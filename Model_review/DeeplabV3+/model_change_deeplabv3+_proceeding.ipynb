# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import utils, layers, models, applications

# %%
# Entry Flow

def entry_flow(x) : 
  y = layers.Conv2D(filters = 32, kernel_size = (3,3), strides = (2,2))(x)
  y = layers.BatchNormalization()(y)
  y = layers.Activation('relu')(y)
  y = layers.Conv2D(filters = 64, kernel_size = (3,3))(y)
  y = layers.BatchNormalization()(y)
  y = layers.Activation('relu')(y)

  r = layers.Conv2D(128, kernel_size = (1,1), strides = (2,2))(y)

  y = layers.SeparableConv2D(filters = 128, kernel_size = (3,3))(y)
  y = layers.BatchNormalization()(y)
  y = layers.Activation('relu')(y)
  y = layers.SeparableConv2D(filters = 128, kernel_size = (3,3))(y)
  y = layers.BatchNormalization()(y)
  y = layers.Activation('relu')(y)
  y = layers.SeparableConv2D(filters = 128, kernel_size = (3,3), strides = (2,2))(y)

  # residual과 resolution이 약간 달라서 reshape
  y = layers.Resizing(r.shape[1], r.shape[2])(y)
  z1 = tf.keras.layers.Add()([y,r])
  z1 = layers.BatchNormalization()(z1)
  z1 = layers.Activation('relu')(z1)


  r = layers.Conv2D(256, kernel_size = (1,1), strides = (2,2))(z1)

  y = layers.SeparableConv2D(filters = 256, kernel_size = (3,3))(z1)
  y = layers.BatchNormalization()(y)
  y = layers.Activation('relu')(y)
  y = layers.SeparableConv2D(filters = 256, kernel_size = (3,3))(y)
  y = layers.BatchNormalization()(y)
  y = layers.Activation('relu')(y)
  y = layers.SeparableConv2D(filters = 256, kernel_size = (3,3), strides = (2,2))(y)
  y = layers.Resizing(r.shape[1], r.shape[2])(y)

  z = tf.keras.layers.Add()([y,r])
  z = layers.BatchNormalization()(z)
  z = layers.Activation('relu')(z)

  r = layers.Conv2D(728, kernel_size = (1,1), strides = (2,2))(z)

  y = layers.SeparableConv2D(filters = 728, kernel_size = (3,3))(z)
  y = layers.BatchNormalization()(y)
  y = layers.Activation('relu')(y)
  y = layers.SeparableConv2D(filters = 728, kernel_size = (3,3))(y)
  y = layers.BatchNormalization()(y)
  y = layers.Activation('relu')(y)
  y = layers.SeparableConv2D(filters = 728, kernel_size = (3,3), strides = (2,2))(y)
  y = layers.Resizing(r.shape[1], r.shape[2])(y)

  z = tf.keras.layers.Add()([y,r])
  z = layers.BatchNormalization()(z)
  z = layers.Activation('relu')(z)

  return z,z1

# %%
# Middle flow

def middle_flow(x) :
  y = layers.SeparableConv2D(filters = 728, kernel_size = (3,3))(x)
  y = layers.BatchNormalization()(y)
  y = layers.Activation('relu')(y)
  y = layers.SeparableConv2D(filters = 728, kernel_size = (3,3))(y)
  y = layers.BatchNormalization()(y)
  y = layers.Activation('relu')(y)
  y = layers.SeparableConv2D(filters = 728, kernel_size = (3,3))(y) 
  y = layers.Resizing(x.shape[1], x.shape[2])(y)

  z = tf.keras.layers.Add()([y,x])
  z = layers.BatchNormalization()(z)
  z = layers.Activation('relu')(z)
  return z

# %%
# Exit flow

def exit_flow(x) :
  y = layers.SeparableConv2D(filters = 728, kernel_size = (3,3))(x)
  y = layers.BatchNormalization()(y)
  y = layers.Activation('relu')(y)
  y = layers.SeparableConv2D(filters = 1024, kernel_size = (3,3))(y)
  y = layers.BatchNormalization()(y)
  y = layers.Activation('relu')(y)
  y = layers.SeparableConv2D(filters = 1024, kernel_size = (3,3), strides = (2,2))(y)
  x = layers.SeparableConv2D(filters = 1024, kernel_size = (1,1), strides = (1,1))(x)
  y = layers.Resizing(x.shape[1], x.shape[2])(y)


  z = tf.keras.layers.Add()([y,x])
  z = layers.BatchNormalization()(z)
  z = layers.Activation('relu')(z)

  y = layers.SeparableConv2D(filters = 1536, kernel_size = (3,3))(z)
  y = layers.BatchNormalization()(y)
  y = layers.Activation('relu')(y)
  y = layers.SeparableConv2D(filters = 1536, kernel_size = (3,3))(y)
  y = layers.BatchNormalization()(y)
  y = layers.Activation('relu')(y)
  y = layers.SeparableConv2D(filters = 2048, kernel_size = (3,3))(y)
  return y

# %%
def decoder(low_img, aspp_img) :
  from tensorflow._api.v2.image import ResizeMethod
  low_level_img = layers.Conv2D(2048, kernel_size = (1,1))(low_img)   # ASPP 통과한 이미지와 채널 수 맞춤

  size = (low_img.shape[1],low_img.shape[2]) # resize img
  ASPP_img = tf.image.resize(aspp_img, size = size, method = ResizeMethod.BILINEAR)    # low level 이미지와 ASPP 통과한 이미지 resolution 맞춤

  concat_img = tf.keras.layers.Add()([low_level_img, ASPP_img])

  concat_img = layers.Conv2D(2, kernel_size = (3,3))(concat_img)
  img = tf.image.resize(concat_img, size = (500,500), method = ResizeMethod.BILINEAR)

  return img

# %%
# optimizer
def dice_coef(y_true, y_pred, smooth=1):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)


# loss
def weighted_loss(y_true, y_pred):
# Calculate the base loss
  from tensorflow.keras.losses import binary_crossentropy
  bc = binary_crossentropy(y_true, y_pred)
  # Apply the weights
  one_weight = 1.0
  zero_weight = 1e-2
  weight_vector = y_true * one_weight + (1. - y_true) * zero_weight
  weight_vector = K.squeeze(weight_vector, axis=-1)
  weighted_ce = weight_vector * bc
  # Return the mean error
  return K.mean(weighted_ce)

# %%
def deeplabv3(input_shape) :
  x = layers.Input(input_shape)
  z, low_level_feature = entry_flow(x)
  z = middle_flow(z)
  ASPP_feature = exit_flow(z)
  output =  decoder(low_level_feature, ASPP_feature)
  model = models.Model(x, output)
  model.compile(loss=weighted_loss, optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),metrics=['accuracy', dice_coef])
  return model

input_shape = (500,500,1)
deeplabv3(input_shape)

# %%
from tensorflow._api.v2.image import ResizeMethod


# entry_flow
input_shape = (500,500,1)
x = layers.Input(input_shape)
y = layers.Conv2D(filters = 32, kernel_size = (3,3), strides = (2,2))(x)
y = layers.BatchNormalization()(y)
y = layers.Activation('relu')(y)
y = layers.Conv2D(filters = 64, kernel_size = (3,3))(y)
y = layers.BatchNormalization()(y)
y = layers.Activation('relu')(y)

r = layers.Conv2D(128, kernel_size = (1,1), strides = (2,2))(y)

y = layers.SeparableConv2D(filters = 128, kernel_size = (3,3))(y)
y = layers.BatchNormalization()(y)
y = layers.Activation('relu')(y)
y = layers.SeparableConv2D(filters = 128, kernel_size = (3,3))(y)
y = layers.BatchNormalization()(y)
y = layers.Activation('relu')(y)
y = layers.SeparableConv2D(filters = 128, kernel_size = (3,3), strides = (2,2))(y)

# residual과 resolution이 약간 달라서 reshape
y = layers.Resizing(r.shape[1], r.shape[2])(y)
z1 = tf.concat([y,r],axis = -1 )
z1 = layers.BatchNormalization()(z1)
z1 = layers.Activation('relu')(z1)


r = layers.Conv2D(256, kernel_size = (1,1), strides = (2,2))(z1)

y = layers.SeparableConv2D(filters = 256, kernel_size = (3,3))(z1)
y = layers.BatchNormalization()(y)
y = layers.Activation('relu')(y)
y = layers.SeparableConv2D(filters = 256, kernel_size = (3,3))(y)
y = layers.BatchNormalization()(y)
y = layers.Activation('relu')(y)
y = layers.SeparableConv2D(filters = 256, kernel_size = (3,3), strides = (2,2))(y)
y = layers.Resizing(r.shape[1], r.shape[2])(y)

z = tf.concat([y,r], axis = -1)
z = layers.BatchNormalization()(z)
z = layers.Activation('relu')(z)

r = layers.Conv2D(728, kernel_size = (1,1), strides = (2,2))(z)

y = layers.SeparableConv2D(filters = 728, kernel_size = (3,3))(z)
y = layers.BatchNormalization()(y)
y = layers.Activation('relu')(y)
y = layers.SeparableConv2D(filters = 728, kernel_size = (3,3))(y)
y = layers.BatchNormalization()(y)
y = layers.Activation('relu')(y)
y = layers.SeparableConv2D(filters = 728, kernel_size = (3,3), strides = (2,2))(y)
y = layers.Resizing(r.shape[1], r.shape[2])(y)

z = tf.concat([y,r], axis = -1)
z = layers.BatchNormalization()(z)
z = layers.Activation('relu')(z)


# middle_flow

y = layers.SeparableConv2D(filters = 728, kernel_size = (3,3))(z)
y = layers.BatchNormalization()(y)
y = layers.Activation('relu')(y)
y = layers.SeparableConv2D(filters = 728, kernel_size = (3,3))(y)
y = layers.BatchNormalization()(y)
y = layers.Activation('relu')(y)
y = layers.SeparableConv2D(filters = 728, kernel_size = (3,3))(y) 
y = layers.Resizing(z.shape[1], z.shape[2])(y)

z = tf.concat([y,z], axis = -1)
z = layers.BatchNormalization()(z)
z = layers.Activation('relu')(z)


# exit_flow
y = layers.SeparableConv2D(filters = 728, kernel_size = (3,3))(z)
y = layers.BatchNormalization()(y)
y = layers.Activation('relu')(y)
y = layers.SeparableConv2D(filters = 1024, kernel_size = (3,3))(y)
y = layers.BatchNormalization()(y)
y = layers.Activation('relu')(y)
y = layers.SeparableConv2D(filters = 1024, kernel_size = (3,3), strides = (2,2))(y)

z = layers.SeparableConv2D(filters = 1024, kernel_size = (1,1), strides = (1,1))(z)
y = layers.Resizing(z.shape[1], z.shape[2])(y)

z = tf.concat([y,z], axis = -1)
z = layers.BatchNormalization()(z)
z = layers.Activation('relu')(z)

y = layers.SeparableConv2D(filters = 1536, kernel_size = (3,3))(z)
y = layers.BatchNormalization()(y)
y = layers.Activation('relu')(y)
y = layers.SeparableConv2D(filters = 1536, kernel_size = (3,3))(y)
y = layers.BatchNormalization()(y)
y = layers.Activation('relu')(y)
y = layers.SeparableConv2D(filters = 2048, kernel_size = (3,3))(y)

low_level_img = layers.Conv2D(2048, kernel_size = (1,1))(z1)   # ASPP 통과한 이미지와 채널 수 맞춤

size = (z1.shape[1],z1.shape[2]) # resize img
ASPP_img = tf.image.resize(y, size = size, method = ResizeMethod.BILINEAR)    # low level 이미지와 ASPP 통과한 이미지 resolution 맞춤
print('low_level_img : ',low_level_img.shape, 'ASPP_img : ', ASPP_img.shape)

concat_img = tf.concat([low_level_img, ASPP_img], axis = -1)
print('before 3X3 conv : ', concat_img.shape)
concat_img = layers.Conv2D(2, kernel_size = (3,3))(concat_img)
print('after 3X3 conv : ', concat_img.shape)
y = tf.image.resize(concat_img, size = (500,500), method = ResizeMethod.BILINEAR)


model = models.Model(x,y)
model.summary()
# Out:
# low_level_img :  (None, 124, 124, 2048) ASPP_img :  (None, 124, 124, 2048)
# before 3X3 conv :  (None, 124, 124, 4096)
# after 3X3 conv :  (None, 122, 122, 2)
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_12 (InputLayer)          [(None, 500, 500, 1  0           []
#                                 )]
#
#  conv2d_58 (Conv2D)             (None, 249, 249, 32  320         ['input_12[0][0]']
#                                 )
#
#  batch_normalization_137 (Batch  (None, 249, 249, 32  128        ['conv2d_58[0][0]']
#  Normalization)                 )
#
#  activation_137 (Activation)    (None, 249, 249, 32  0           ['batch_normalization_137[0][0]']
#                                 )
#
#  conv2d_59 (Conv2D)             (None, 247, 247, 64  18496       ['activation_137[0][0]']
#                                 )
#
#  batch_normalization_138 (Batch  (None, 247, 247, 64  256        ['conv2d_59[0][0]']
#  Normalization)                 )
#
#  activation_138 (Activation)    (None, 247, 247, 64  0           ['batch_normalization_138[0][0]']
#                                 )
#
#  separable_conv2d_132 (Separabl  (None, 245, 245, 12  8896       ['activation_138[0][0]']
#  eConv2D)                       8)
#
#  batch_normalization_139 (Batch  (None, 245, 245, 12  512        ['separable_conv2d_132[0][0]']
#  Normalization)                 8)
#
#  activation_139 (Activation)    (None, 245, 245, 12  0           ['batch_normalization_139[0][0]']
#                                 8)
#
#  separable_conv2d_133 (Separabl  (None, 243, 243, 12  17664      ['activation_139[0][0]']
#  eConv2D)                       8)
#
#  batch_normalization_140 (Batch  (None, 243, 243, 12  512        ['separable_conv2d_133[0][0]']
#  Normalization)                 8)
#
#  activation_140 (Activation)    (None, 243, 243, 12  0           ['batch_normalization_140[0][0]']
#                                 8)
#
#  separable_conv2d_134 (Separabl  (None, 121, 121, 12  17664      ['activation_140[0][0]']
#  eConv2D)                       8)
#
#  resizing_36 (Resizing)         (None, 124, 124, 12  0           ['separable_conv2d_134[0][0]']
#                                 8)
#
#  conv2d_60 (Conv2D)             (None, 124, 124, 12  8320        ['activation_138[0][0]']
#                                 8)
#
#  tf.concat_1 (TFOpLambda)       (None, 124, 124, 25  0           ['resizing_36[0][0]',
#                                 6)                                'conv2d_60[0][0]']
#
#  batch_normalization_141 (Batch  (None, 124, 124, 25  1024       ['tf.concat_1[0][0]']
#  Normalization)                 6)
#
#  activation_141 (Activation)    (None, 124, 124, 25  0           ['batch_normalization_141[0][0]']
#                                 6)
#
#  separable_conv2d_135 (Separabl  (None, 122, 122, 25  68096      ['activation_141[0][0]']
#  eConv2D)                       6)
#
#  batch_normalization_142 (Batch  (None, 122, 122, 25  1024       ['separable_conv2d_135[0][0]']
#  Normalization)                 6)
#
#  activation_142 (Activation)    (None, 122, 122, 25  0           ['batch_normalization_142[0][0]']
#                                 6)
#
#  separable_conv2d_136 (Separabl  (None, 120, 120, 25  68096      ['activation_142[0][0]']
#  eConv2D)                       6)
#
#  batch_normalization_143 (Batch  (None, 120, 120, 25  1024       ['separable_conv2d_136[0][0]']
#  Normalization)                 6)
#
#  activation_143 (Activation)    (None, 120, 120, 25  0           ['batch_normalization_143[0][0]']
#                                 6)
#
#  separable_conv2d_137 (Separabl  (None, 59, 59, 256)  68096      ['activation_143[0][0]']
#  eConv2D)
#
#  resizing_37 (Resizing)         (None, 62, 62, 256)  0           ['separable_conv2d_137[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 62, 62, 256)  65792       ['activation_141[0][0]']
#
#  tf.concat_2 (TFOpLambda)       (None, 62, 62, 512)  0           ['resizing_37[0][0]',
#                                                                   'conv2d_61[0][0]']
#
#  batch_normalization_144 (Batch  (None, 62, 62, 512)  2048       ['tf.concat_2[0][0]']
#  Normalization)
#
#  activation_144 (Activation)    (None, 62, 62, 512)  0           ['batch_normalization_144[0][0]']
#
#  separable_conv2d_138 (Separabl  (None, 60, 60, 728)  378072     ['activation_144[0][0]']
#  eConv2D)
#
#  batch_normalization_145 (Batch  (None, 60, 60, 728)  2912       ['separable_conv2d_138[0][0]']
#  Normalization)
#
#  activation_145 (Activation)    (None, 60, 60, 728)  0           ['batch_normalization_145[0][0]']
#
#  separable_conv2d_139 (Separabl  (None, 58, 58, 728)  537264     ['activation_145[0][0]']
#  eConv2D)
#
#  batch_normalization_146 (Batch  (None, 58, 58, 728)  2912       ['separable_conv2d_139[0][0]']
#  Normalization)
#
#  activation_146 (Activation)    (None, 58, 58, 728)  0           ['batch_normalization_146[0][0]']
#
#  separable_conv2d_140 (Separabl  (None, 28, 28, 728)  537264     ['activation_146[0][0]']
#  eConv2D)
#
#  resizing_38 (Resizing)         (None, 31, 31, 728)  0           ['separable_conv2d_140[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 31, 31, 728)  373464      ['activation_144[0][0]']
#
#  tf.concat_3 (TFOpLambda)       (None, 31, 31, 1456  0           ['resizing_38[0][0]',
#                                 )                                 'conv2d_62[0][0]']
#
#  batch_normalization_147 (Batch  (None, 31, 31, 1456  5824       ['tf.concat_3[0][0]']
#  Normalization)                 )
#
#  activation_147 (Activation)    (None, 31, 31, 1456  0           ['batch_normalization_147[0][0]']
#                                 )
#
#  separable_conv2d_141 (Separabl  (None, 29, 29, 728)  1073800    ['activation_147[0][0]']
#  eConv2D)
#
#  batch_normalization_148 (Batch  (None, 29, 29, 728)  2912       ['separable_conv2d_141[0][0]']
#  Normalization)
#
#  activation_148 (Activation)    (None, 29, 29, 728)  0           ['batch_normalization_148[0][0]']
#
#  separable_conv2d_142 (Separabl  (None, 27, 27, 728)  537264     ['activation_148[0][0]']
#  eConv2D)
#
#  batch_normalization_149 (Batch  (None, 27, 27, 728)  2912       ['separable_conv2d_142[0][0]']
#  Normalization)
#
#  activation_149 (Activation)    (None, 27, 27, 728)  0           ['batch_normalization_149[0][0]']
#
#  separable_conv2d_143 (Separabl  (None, 25, 25, 728)  537264     ['activation_149[0][0]']
#  eConv2D)
#
#  resizing_39 (Resizing)         (None, 31, 31, 728)  0           ['separable_conv2d_143[0][0]']
#
#  tf.concat_4 (TFOpLambda)       (None, 31, 31, 2184  0           ['resizing_39[0][0]',
#                                 )                                 'activation_147[0][0]']
#
#  batch_normalization_150 (Batch  (None, 31, 31, 2184  8736       ['tf.concat_4[0][0]']
#  Normalization)                 )
#
#  activation_150 (Activation)    (None, 31, 31, 2184  0           ['batch_normalization_150[0][0]']
#                                 )
#
#  separable_conv2d_144 (Separabl  (None, 29, 29, 728)  1610336    ['activation_150[0][0]']
#  eConv2D)
#
#  batch_normalization_151 (Batch  (None, 29, 29, 728)  2912       ['separable_conv2d_144[0][0]']
#  Normalization)
#
#  activation_151 (Activation)    (None, 29, 29, 728)  0           ['batch_normalization_151[0][0]']
#
#  separable_conv2d_145 (Separabl  (None, 27, 27, 1024  753048     ['activation_151[0][0]']
#  eConv2D)                       )
#
#  batch_normalization_152 (Batch  (None, 27, 27, 1024  4096       ['separable_conv2d_145[0][0]']
#  Normalization)                 )
#
#  activation_152 (Activation)    (None, 27, 27, 1024  0           ['batch_normalization_152[0][0]']
#                                 )
#
#  separable_conv2d_146 (Separabl  (None, 13, 13, 1024  1058816    ['activation_152[0][0]']
#  eConv2D)                       )
#
#  resizing_40 (Resizing)         (None, 31, 31, 1024  0           ['separable_conv2d_146[0][0]']
#                                 )
#
#  separable_conv2d_147 (Separabl  (None, 31, 31, 1024  2239624    ['activation_150[0][0]']
#  eConv2D)                       )
#
#  tf.concat_5 (TFOpLambda)       (None, 31, 31, 2048  0           ['resizing_40[0][0]',
#                                 )                                 'separable_conv2d_147[0][0]']
#
#  batch_normalization_153 (Batch  (None, 31, 31, 2048  8192       ['tf.concat_5[0][0]']
#  Normalization)                 )
#
#  activation_153 (Activation)    (None, 31, 31, 2048  0           ['batch_normalization_153[0][0]']
#                                 )
#
#  separable_conv2d_148 (Separabl  (None, 29, 29, 1536  3165696    ['activation_153[0][0]']
#  eConv2D)                       )
#
#  batch_normalization_154 (Batch  (None, 29, 29, 1536  6144       ['separable_conv2d_148[0][0]']
#  Normalization)                 )
#
#  activation_154 (Activation)    (None, 29, 29, 1536  0           ['batch_normalization_154[0][0]']
#                                 )
#
#  separable_conv2d_149 (Separabl  (None, 27, 27, 1536  2374656    ['activation_154[0][0]']
#  eConv2D)                       )
#
#  batch_normalization_155 (Batch  (None, 27, 27, 1536  6144       ['separable_conv2d_149[0][0]']
#  Normalization)                 )
#
#  activation_155 (Activation)    (None, 27, 27, 1536  0           ['batch_normalization_155[0][0]']
#                                 )
#
#  separable_conv2d_150 (Separabl  (None, 25, 25, 2048  3161600    ['activation_155[0][0]']
#  eConv2D)                       )
#
#  conv2d_63 (Conv2D)             (None, 124, 124, 20  526336      ['activation_141[0][0]']
#                                 48)
#
#  tf.image.resize_12 (TFOpLambda  (None, 124, 124, 20  0          ['separable_conv2d_150[0][0]']
#  )                              48)
#
#  tf.concat_6 (TFOpLambda)       (None, 124, 124, 40  0           ['conv2d_63[0][0]',
#                                 96)                               'tf.image.resize_12[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 122, 122, 2)  73730       ['tf.concat_6[0][0]']
#
#  tf.image.resize_13 (TFOpLambda  (None, 500, 500, 2)  0          ['conv2d_64[0][0]']
#  )
#
# ==================================================================================================
# Total params: 19,339,898
# Trainable params: 19,309,786
# Non-trainable params: 30,112
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model, show_shapes = True)

# %%
from tensorflow.keras import optimizers
model.compile(loss=weighted_loss, optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),metrics=['accuracy', dice_coef])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-953c639227ca> in <module>
#       1 from tensorflow.keras import optimizers
# ----> 2 model.compile(loss=weighted_loss, optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),metrics=['accuracy', dice_coef])
#
# NameError: name 'weighted_loss' is not defined
